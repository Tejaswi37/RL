# %% [markdown]
# <a href="https://colab.research.google.com/github/Tejaswi37/RL/blob/main/Assignment_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import gymnasium as gym

def random_agent(env_name, episodes=5):
    env = gym.make(env_name)

    for episode in range(1, episodes + 1):
        state, info = env.reset()
        total_reward = 0
        steps = 0
        terminated = False
        truncated = False

        while not (terminated or truncated):
            action = env.action_space.sample()
            next_state, reward, terminated, truncated, info = env.step(action)

            total_reward += reward
            steps += 1
            state = next_state

        average_reward = total_reward / steps

        print("Episode:", episode)
        print("Total Reward:", total_reward)
        print("Average Reward:", round(average_reward, 2))
        print()

    env.close()

print("CliffWalking Environment")
random_agent("CliffWalking-v1", 5)

print("Taxi Environment")
random_agent("Taxi-v4", 5)
# Out:
# CliffWalking Environment
# Episode: 1
# Total Reward: -190144
# Average Reward: -10.13
#
# Episode: 2
# Total Reward: -70945
# Average Reward: -9.87
#
# Episode: 3
# Total Reward: -45960
# Average Reward: -9.83
#
# Episode: 4
# Total Reward: -98422
# Average Reward: -9.11
#
# Episode: 5
# Total Reward: -19979
# Average Reward: -10.19
#
# Taxi Environment
# Episode: 1
# Total Reward: -677
# Average Reward: -3.38
#
# Episode: 2
# Total Reward: -812
# Average Reward: -4.06
#
# Episode: 3
# Total Reward: -812
# Average Reward: -4.06
#
# Episode: 4
# Total Reward: -821
# Average Reward: -4.11
#
# Episode: 5
# Total Reward: -749
# Average Reward: -3.75
